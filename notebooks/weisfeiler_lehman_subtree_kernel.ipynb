# %%
# Navigate to appropriate directory
import os
while os.path.split(os.getcwd())[1] != "data-challenge-kernel-methods":
    os.chdir("..")
    if os.getcwd() == "/":
        raise ValueError()

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from time import time
from tqdm import tqdm
import pickle
import networkx as nx

from molecules import Molecule
from kernels import wlsk

# %%
with open("data/training_data.pkl", "rb") as file:
    training_data = pickle.load(file)

with open("data/training_labels.pkl", "rb") as file:
    training_labels = pickle.load(file)

# %%
training_data = [Molecule(graph) for graph in training_data]

# %%
mol1, mol2 = training_data[:2]

# %%
mol1.plot()

# %%
mol2.plot()

# %%
wlsk(mol1, mol2, n_iter=0)
# Out:
# 263

# %%
mol1.node_label_frequencies()
# Out:
# {1: 13, 2: 1, 0: 2}

# %%
mol2.node_label_frequencies()
# Out:
# {1: 20, 2: 3, 4: 1}

# %%
mol1b, _, _ = mol1.wl_relabeling()

# %%
mol1b.plot()

# %%
mol1c, _, _ = mol1b.wl_relabeling()

# %%
mol1c.plot()
